# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/TALABI/Desktop/Sanddata.csv', header=0)

# %%
df.head()
# Out:
#         Vsl  Dpipe m  particle, m  rhos, kg/m3  Cv [v/v]  rhol, kg/m3  \
# 0  0.425852   0.0254     0.000144         2650    0.0020         1000
# 1  0.477387   0.0254     0.000144         2650    0.0050         1000
# 2  0.528967   0.0254     0.000144         2650    0.0075         1000
# 3  0.757576   0.0254     0.000144         2650    0.0100         1000
# 4  1.105263   0.0254     0.000144         2650    0.0500         1000
#
#    visco Pa.s  theta  Vc m/s
# 0       0.001      0   0.425
# 1       0.001      0   0.475
# 2       0.001      0   0.525
# 3       0.001      0   0.750
# 4       0.001      0   1.050

# %%
df.shape
# Out:
# (182, 9)

# %%
df.describe()
# Out:
#               Vsl     Dpipe m  particle, m  rhos, kg/m3    Cv [v/v]  \
# count  182.000000  182.000000   182.000000        182.0  182.000000
# mean     2.117932    0.100145     0.000369       2650.0    0.120112
# std      1.805176    0.090519     0.000370          0.0    0.142724
# min      0.070008    0.009398     0.000100       2650.0    0.000020
# 25%      0.798506    0.050800     0.000200       2650.0    0.010000
# 50%      1.521253    0.100000     0.000360       2650.0    0.100000
# 75%      2.989264    0.100000     0.000360       2650.0    0.120000
# max      8.371575    0.701040     0.003700       2650.0    0.600000
#
#        rhol, kg/m3  visco Pa.s       theta      Vc m/s
# count   182.000000  182.000000  182.000000  182.000000
# mean    992.401099    0.001291    4.510989    1.636426
# std      75.576887    0.002350   11.365713    1.009161
# min       3.000000    0.001000  -25.000000    0.070000
# 25%    1000.000000    0.001000    0.000000    0.765092
# ...

# %%
sns.jointplot(x='Vsl', y='Vc m/s', data=df)

# %%
sns.jointplot(x="Dpipe m", y="particle, m", data=df)

# %%
df['particle, m']= np.log(df['particle, m'])

# %%
sns.jointplot(x="Dpipe m", y="particle, m", data=df)

# %%
df.head()
# Out:
#         Vsl  Dpipe m  particle, m  rhos, kg/m3  Cv [v/v]  rhol, kg/m3  \
# 0  0.425852   0.0254     0.000144         2650    0.0020         1000
# 1  0.477387   0.0254     0.000144         2650    0.0050         1000
# 2  0.528967   0.0254     0.000144         2650    0.0075         1000
# 3  0.757576   0.0254     0.000144         2650    0.0100         1000
# 4  1.105263   0.0254     0.000144         2650    0.0500         1000
#
#    visco Pa.s  theta  Vc m/s
# 0       0.001      0   0.425
# 1       0.001      0   0.475
# 2       0.001      0   0.525
# 3       0.001      0   0.750
# 4       0.001      0   1.050

# %%
sns.countplot(x="Dpipe m", data=df)
# Out:
# <AxesSubplot:xlabel='Dpipe m', ylabel='count'>

# %%
sns.countplot(x="waterbody", data = df)

# %%
sns.countplot(x="bus_ter", data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
np.percentile(df.n_hot_rooms,[99])
# Out:
# array([15.39952])

# %%
np.percentile(df.n_hot_rooms,[99])[0]
# Out:
# 15.399519999999999

# %%
uv = np.percentile(df.n_hot_rooms,[99])[0]

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
df.n_hot_rooms[(df.n_hot_rooms> 3*uv)] = 3*uv
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
np.percentile(df.rainfall,[1])[0]
# Out:
# 20.0

# %%
lv = np.percentile(df.rainfall,[1])[0]

# %%
df[(df.rainfall< lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
df.rainfall[(df.rainfall <0.3*lv)] = 0.3*lv
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.jointplot(x="crime_rate", y="price", data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
df.n_hos_beds = df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     506 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
sns.jointplot(x="crime_rate", y="price",data=df)

# %%
df.crime_rate = np.log(1+df.crime_rate)

# %%
sns.jointplot(x="crime_rate", y="price",data=df)

# %%
df['avg_dist'] = (df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
del df['dist1']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist2       dist3       dist4    teachers   poor_prop  n_hos_beds  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.628775    3.960672    3.618972   21.544466   12.653063    7.899767
# ...

# %%
del df['dist2']

# %%
del df['dist3']

# %%
del df['dist4']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.864050   39.187747
# ...

# %%
del df['bus_ter']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480     11.19200     River        23  0.049347
# 1       9.14      NO       7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO       7.394     46.19856      None        38  0.045764
# 3       2.94     YES       9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO       8.824     11.28960      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#         Vsl  Dpipe m  particle, m  rhos, kg/m3  Cv [v/v]  rhol, kg/m3  \
# 0  0.425852   0.0254     0.000144         2650    0.0020         1000
# 1  0.477387   0.0254     0.000144         2650    0.0050         1000
# 2  0.528967   0.0254     0.000144         2650    0.0075         1000
# 3  0.757576   0.0254     0.000144         2650    0.0100         1000
# 4  1.105263   0.0254     0.000144         2650    0.0500         1000
#
#    visco Pa.s  theta  Vc m/s
# 0       0.001      0   0.425
# 1       0.001      0   0.475
# 2       0.001      0   0.525
# 3       0.001      0   0.750
# 4       0.001      0   1.050

# %%
del df['airport_NO']

# %%
del df['waterbody_None']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
df.corr()
# Out:
#                   Vsl   Dpipe m  particle, m  rhos, kg/m3  Cv [v/v]  \
# Vsl          1.000000  0.375462     0.183841          NaN  0.886396
# Dpipe m      0.375462  1.000000     0.149233          NaN  0.081756
# particle, m  0.183841  0.149233     1.000000          NaN  0.086131
# rhos, kg/m3       NaN       NaN          NaN          NaN       NaN
# Cv [v/v]     0.886396  0.081756     0.086131          NaN  1.000000
# rhol, kg/m3  0.069895 -0.019441     0.060583          NaN  0.078000
# visco Pa.s  -0.083984  0.023470    -0.074516          NaN -0.095938
# theta        0.212617 -0.084766    -0.068858          NaN  0.116662
# Vc m/s       0.895426  0.584472     0.286693          NaN  0.676497
#
#              rhol, kg/m3  visco Pa.s     theta    Vc m/s
# Vsl             0.069895   -0.083984  0.212617  0.895426
# Dpipe m        -0.019441    0.023470 -0.084766  0.584472
# particle, m     0.060583   -0.074516 -0.068858  0.286693
# rhos, kg/m3          NaN         NaN       NaN       NaN
# ...

# %%
del df['parks']

# %%
df.head()
# Out:
#         Vsl  Dpipe m  particle, m  rhos, kg/m3  Cv [v/v]  rhol, kg/m3  \
# 0  0.425852   0.0254     0.000144         2650    0.0020         1000
# 1  0.477387   0.0254     0.000144         2650    0.0050         1000
# 2  0.528967   0.0254     0.000144         2650    0.0075         1000
# 3  0.757576   0.0254     0.000144         2650    0.0100         1000
# 4  1.105263   0.0254     0.000144         2650    0.0500         1000
#
#    visco Pa.s  theta  Vc m/s
# 0       0.001      0   0.425
# 1       0.001      0   0.475
# 2       0.001      0   0.525
# 3       0.001      0   0.750
# 4       0.001      0   1.050

# %%
import statsmodels.api as sn

# %%
X = sn.add_constant(df['Vsl'])

# %%
lm = sn.OLS(df['Vc m/s'], X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Vc m/s   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     728.1
# Date:                Fri, 18 Feb 2022   Prob (F-statistic):           3.66e-65
# Time:                        14:14:01   Log-Likelihood:                -112.13
# No. Observations:                 182   AIC:                             228.3
# Df Residuals:                     180   BIC:                             234.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5762      0.052     11.175      0.000       0.474       0.678
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df['Vc m/s']

# %%
X = df[['Vsl']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_, lm2.coef_)
# Out:
# 0.5762393171190732 [0.50057639]

# %%
lm2.predict(X)
# Out:
# array([0.78941063, 0.81520795, 0.84102784, 0.95546386, 1.12950796,
#        1.21586471, 0.76414337, 0.78439483, 0.81772341, 0.84102784,
#        0.89731609, 0.95873102, 1.03993113, 0.88150496, 0.94294439,
#        0.95739032, 0.97189692, 0.98635802, 1.01493638, 1.03410997,
#        1.02980198, 0.99733025, 0.96016118, 0.90420787, 0.88439006,
#        1.20403362, 1.26191149, 1.27658145, 1.31031417, 1.31545273,
#        1.31584604, 1.30671819, 1.25955163, 1.17904567, 1.34164697,
#        1.44026579, 1.47012648, 1.49998718, 1.51510459, 1.54008599,
#        1.54047591, 1.47707659, 1.48241959, 1.45310162, 1.65406928,
#        1.74778831, 1.79485361, 1.82118949, 1.86308773, 1.85833226,
#        1.82248543, 1.74520199, 1.67308562, 2.22653331, 2.24446646,
#        2.28531349, 2.32659853, 2.32708034, 2.36792111, 2.23429224,
#        2.19519097, 2.1940021 , 2.20612231, 2.15953742, 2.07838773,
#        2.72267513, 2.80318927, 2.83037057, 2.79761142, 2.79818351,
# ...

# %%
sns.jointplot(x = df['Vsl'], y = df['Vc m/s'], data =df, kind = 'reg')
